# %% [markdown]
# <a href="https://colab.research.google.com/github/MDC55/Basic-Deep-Learning/blob/main/Hsi_Fahim.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#https://www.ehu.eus/ccwintco/index.php/Hyperspectral_Remote_Sensing_Scenes#Indian_Pines
#https://github.com/DharmeshPatel33/Land-Cover-Classification-using-Hyper-Spectral-Data-with-Deep-Learning/blob/main/CNN_Hybrid_Spectral_Net.ipynb

# %%
# !pip install spectral
# !pip install keras.utils
# Out:
# Requirement already satisfied: spectral in /usr/local/lib/python3.10/dist-packages (0.23.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from spectral) (1.23.5)
# Requirement already satisfied: keras.utils in /usr/local/lib/python3.10/dist-packages (1.0.13)
# Requirement already satisfied: Keras>=2.1.5 in /usr/local/lib/python3.10/dist-packages (from keras.utils) (2.14.0)

# %%
import os
import scipy.io as sio
import numpy as np
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import keras
from keras.utils import to_categorical as keras_to_categorical
#from keras.utils import np_utils

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
print(os.path.join('/content/drive/MyDrive/','HSI_Dataset'))
# Out:
# /content/drive/MyDrive/HSI_Dataset

# %%
def loadData(name):
    data_path = os.path.join('/content/drive/MyDrive/','HSI_Dataset')
    if name == 'IP':
        data = sio.loadmat(os.path.join(data_path, 'Indian_pines_corrected.mat'))['indian_pines_corrected']
        labels = sio.loadmat(os.path.join(data_path, 'Indian_pines_gt.mat'))['indian_pines_gt']
    elif name == 'SA':
        data = sio.loadmat(os.path.join(data_path, 'Salinas_corrected.mat'))['salinas_corrected']
        labels = sio.loadmat(os.path.join(data_path, 'Salinas_gt.mat'))['salinas_gt']
    elif name == 'PU':
        data = sio.loadmat(os.path.join(data_path, 'PaviaU.mat'))['paviaU']
        labels = sio.loadmat(os.path.join(data_path, 'PaviaU_gt.mat'))['paviaU_gt']

    return data, labels

# %%
def splitTrainTestSet(X, y, testRatio, randomState=345):
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=testRatio, random_state=randomState,
                                                        stratify=y)
    return X_train, X_test, y_train, y_test

# %%
def applyPCA(X, numComponents=75):
    newX = np.reshape(X, (-1, X.shape[2]))
    pca = PCA(n_components=numComponents, whiten=True)
    newX = pca.fit_transform(newX)
    newX = np.reshape(newX, (X.shape[0],X.shape[1], numComponents))
    return newX, pca

# %%
def padWithZeros(X, margin=2):
    newX = np.zeros((X.shape[0] + 2 * margin, X.shape[1] + 2* margin, X.shape[2]))
    x_offset = margin
    y_offset = margin
    newX[x_offset:X.shape[0] + x_offset, y_offset:X.shape[1] + y_offset, :] = X
    return newX

# %%
def createImageCubes(X, y, windowSize=5, removeZeroLabels = True):
    margin = int((windowSize - 1) / 2)
    zeroPaddedX = padWithZeros(X, margin=margin)
    # split patches
    patchesData = np.zeros((X.shape[0] * X.shape[1], windowSize, windowSize, X.shape[2]))
    patchesLabels = np.zeros((X.shape[0] * X.shape[1]))
    patchIndex = 0
    for r in range(margin, zeroPaddedX.shape[0] - margin):
        for c in range(margin, zeroPaddedX.shape[1] - margin):
            patch = zeroPaddedX[r - margin:r + margin + 1, c - margin:c + margin + 1]
            patchesData[patchIndex, :, :, :] = patch
            patchesLabels[patchIndex] = y[r-margin, c-margin]
            patchIndex = patchIndex + 1
    if removeZeroLabels:
        patchesData = patchesData[patchesLabels>0,:,:,:]
        patchesLabels = patchesLabels[patchesLabels>0]
        patchesLabels -= 1
    return patchesData, patchesLabels

# %%
## GLOBAL VARIABLES
dataset = 'IP'
test_ratio = 0.7
windowSize = 25

# %%
X, y = loadData(dataset)

X.shape, y.shape
# Out:
# ((145, 145, 200), (145, 145))

# %%
K = X.shape[2]

# %%
K = 30 if dataset == 'IP' else 15
X,pca = applyPCA(X,numComponents=K)

X.shape
# Out:
# (145, 145, 30)

# %%
X, y = createImageCubes(X, y, windowSize=windowSize)

X.shape, y.shape
# Out:
# ((10249, 25, 25, 30), (10249,))

# %%
Xtrain, Xtest, ytrain, ytest = splitTrainTestSet(X, y, test_ratio)

Xtrain.shape, Xtest.shape, ytrain.shape, ytest.shape
# Out:
# ((3074, 25, 25, 30), (7175, 25, 25, 30), (3074,), (7175,))

# %% [markdown]
# ##Model and Training

# %%
Xtrain = Xtrain.reshape(-1, windowSize, windowSize, K, 1)
Xtrain.shape
# Out:
# (3074, 25, 25, 30, 1)

# %%
ytrain = keras_to_categorical(ytrain)
ytrain.shape
# Out:
# (3074, 16)

# %%
S = windowSize
L = K
output_units = 9 if (dataset == 'PU' or dataset == 'PC') else 16 #number of classes

# %%
import tensorflow as tf
import numpy as np

from tensorflow import keras
from tensorflow.keras.layers import *
from tensorflow.keras.models import *
from tensorflow.keras.callbacks import *
from matplotlib import pyplot as plt
from tensorflow.keras import backend as K
from tensorflow.keras.regularizers import *
from tensorflow import (abs,cast,clip_by_value,complex,concat,convert_to_tensor,expand_dims,gather,gather_nd,linspace,map_fn,matmul,

    norm, pad,print,range,repeat,reshape,shape,sign,split, squeeze, stack, tensor_scatter_nd_update,tile, transpose, unstack, zeros,)

# %%
def normed_activation_block(x):
    x = Activation("gelu")(x)
    return BatchNormalization()(x)


def conv_stem(x, filters: int, patch_size: int):
    x = Conv2D(filters, kernel_size=patch_size, strides=patch_size)(x)
    return normed_activation_block(x)

def channel_attn(ftr_block,filters):
  z = GlobalAveragePooling2D()(ftr_block)
  z = tf.expand_dims(z,1)
  z = tf.expand_dims(z,1)
  z=Conv2D(filters//4, (3,3),padding='same',activation='relu')(z)
  z=Conv2D(filters, (3,3),padding='same',activation='sigmoid')(z)
  mul=Multiply()([z, ftr_block])
  return mul

def mixer_block(x, filters: int, kernel_size: int):
    # Depthwise convolution.
    x0 = x
    y1 = DepthwiseConv2D(kernel_size=1, padding="same")(x)
    y2 = DepthwiseConv2D(kernel_size=3, padding="same")(x)
    y3 = DepthwiseConv2D(kernel_size=5, padding="same")(x)
    x = Add()([normed_activation_block(y1),normed_activation_block(y2),normed_activation_block(y3), x0])  # Residual.
    # Pointwise convolution.
    x = Conv2D(filters, kernel_size=1)(x)
    z1 = channel_attn(x,filters)
    x = Add()([z1, x])
    x = normed_activation_block(x)
    return x


def mixer_256_8(image_size=224, filters=256, depth=8, kernel_size=5, patch_size=2, num_classes=10):
    inputs = keras.Input((image_size, image_size, 3))
    x = Rescaling(scale=1.0 / 255)(inputs)
    # Extract patch embeddings.
    x = conv_stem(x, filters, patch_size)
    # Mixer blocks.
    for _ in range(depth):
        x = mixer_block(x, filters, kernel_size)
    # Classification block.
    x = GlobalAvgPool2D()(x)
    outputs = Dense(num_classes, activation="softmax")(x)
    return keras.Model(inputs, outputs)


def mixer_layer(image_ftr, filters=256, depth=8, kernel_size=5, patch_size=2):
    # Extract patch embeddings.
    x = conv_stem(image_ftr, filters, patch_size)
    # Mixer blocks.
    for _ in range(depth):
        x = mixer_block(x, filters, kernel_size)
    x = GlobalAvgPool2D()(x)
    return x


def mixer_ops(image_input, filters=256, depth=8, kernel_size=5, patch_size=2):
    x_low = Conv2D(3, (1,1),padding='same',activation='relu')(image_input)
    x_low = MaxPooling2D()(x_low)
    x_base = Conv2D(3, (3,3),padding='same',activation='relu')(image_input)
    x_high = Conv2D(3, (5,5),padding='same',activation='relu')(image_input)
    x_high = UpSampling2D()(x_high)
    x_low_embd = mixer_layer(x_low,filters, depth, kernel_size, patch_size)
    x_base_embd = mixer_layer(x_base,filters, depth, kernel_size, patch_size)
    x_high_embd = mixer_layer(x_high,filters, depth, kernel_size, patch_size)
    outputs =  concatenate([x_low_embd, x_base_embd, x_high_embd])
    return outputs

# %% [markdown]
# **Xtrain r shape: (3074, 25, 25, 30, 1)= (batch, height, width, band, channel)**
#
# **Batch dim r por, extra dim 4 ta, so 3D data but amra are 2D diya porcess korbo**

# %% [markdown]
#  **Tar age amra 2D backbone banai, jeta 3D data r jonno babohar kora hoibe.**
#
#  **Sei 2D backbone input jabe Batch dim r por extra 3 ta dims: (H, W, Channel)**

# %%
# First define the 2D model as the trainable beackbone

filters = 64
kernel_size = 5
dropout = 0.3
patch_size = 2
depths = 8


##--------------------------------------------------------------------
Batch_dim, height_dim, width_dim, band_dim, cahnnel_dim = Xtrain.shape



##--------------------------------------------------------------------
inputs = Input((height_dim,width_dim, cahnnel_dim))

cb_y = mixer_ops(inputs, filters, depths, kernel_size, patch_size )
bone_mixer =  Model(inputs=inputs, outputs=cb_y )
bone_mixer.trainable = True

bone_mixer.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 25, 25, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 25, 25, 3)            6         ['input_1[0][0]']
#
#  conv2d_2 (Conv2D)           (None, 25, 25, 3)            78        ['input_1[0][0]']
#
#  max_pooling2d (MaxPooling2  (None, 12, 12, 3)            0         ['conv2d[0][0]']
#  D)
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 3)            30        ['input_1[0][0]']
#
#  up_sampling2d (UpSampling2  (None, 50, 50, 3)            0         ['conv2d_2[0][0]']
#  D)
#
#  conv2d_3 (Conv2D)           (None, 6, 6, 64)             832       ['max_pooling2d[0][0]']
#
#  conv2d_28 (Conv2D)          (None, 12, 12, 64)           832       ['conv2d_1[0][0]']
#
#  conv2d_53 (Conv2D)          (None, 25, 25, 64)           832       ['up_sampling2d[0][0]']
#
#  activation (Activation)     (None, 6, 6, 64)             0         ['conv2d_3[0][0]']
#
#  activation_33 (Activation)  (None, 12, 12, 64)           0         ['conv2d_28[0][0]']
#
#  activation_66 (Activation)  (None, 25, 25, 64)           0         ['conv2d_53[0][0]']
#
#  batch_normalization (Batch  (None, 6, 6, 64)             256       ['activation[0][0]']
#  Normalization)
#
#  batch_normalization_33 (Ba  (None, 12, 12, 64)           256       ['activation_33[0][0]']
#  tchNormalization)
#
#  batch_normalization_66 (Ba  (None, 25, 25, 64)           256       ['activation_66[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d (Depthwis  (None, 6, 6, 64)             128       ['batch_normalization[0][0]']
#  eConv2D)
#
#  depthwise_conv2d_1 (Depthw  (None, 6, 6, 64)             640       ['batch_normalization[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_2 (Depthw  (None, 6, 6, 64)             1664      ['batch_normalization[0][0]']
#  iseConv2D)
#
#  depthwise_conv2d_24 (Depth  (None, 12, 12, 64)           128       ['batch_normalization_33[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_25 (Depth  (None, 12, 12, 64)           640       ['batch_normalization_33[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_26 (Depth  (None, 12, 12, 64)           1664      ['batch_normalization_33[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_48 (Depth  (None, 25, 25, 64)           128       ['batch_normalization_66[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_49 (Depth  (None, 25, 25, 64)           640       ['batch_normalization_66[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_50 (Depth  (None, 25, 25, 64)           1664      ['batch_normalization_66[0][0]
#  wiseConv2D)                                                        ']
#
#  activation_1 (Activation)   (None, 6, 6, 64)             0         ['depthwise_conv2d[0][0]']
#
#  activation_2 (Activation)   (None, 6, 6, 64)             0         ['depthwise_conv2d_1[0][0]']
#
#  activation_3 (Activation)   (None, 6, 6, 64)             0         ['depthwise_conv2d_2[0][0]']
#
#  activation_34 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_24[0][0]']
#
#  activation_35 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_25[0][0]']
#
#  activation_36 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_26[0][0]']
#
#  activation_67 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_48[0][0]']
#
#  activation_68 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_49[0][0]']
#
#  activation_69 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_50[0][0]']
#
#  batch_normalization_1 (Bat  (None, 6, 6, 64)             256       ['activation_1[0][0]']
#  chNormalization)
#
#  batch_normalization_2 (Bat  (None, 6, 6, 64)             256       ['activation_2[0][0]']
#  chNormalization)
#
#  batch_normalization_3 (Bat  (None, 6, 6, 64)             256       ['activation_3[0][0]']
#  chNormalization)
#
#  batch_normalization_34 (Ba  (None, 12, 12, 64)           256       ['activation_34[0][0]']
#  tchNormalization)
#
#  batch_normalization_35 (Ba  (None, 12, 12, 64)           256       ['activation_35[0][0]']
#  tchNormalization)
#
#  batch_normalization_36 (Ba  (None, 12, 12, 64)           256       ['activation_36[0][0]']
#  tchNormalization)
#
#  batch_normalization_67 (Ba  (None, 25, 25, 64)           256       ['activation_67[0][0]']
#  tchNormalization)
#
#  batch_normalization_68 (Ba  (None, 25, 25, 64)           256       ['activation_68[0][0]']
#  tchNormalization)
#
#  batch_normalization_69 (Ba  (None, 25, 25, 64)           256       ['activation_69[0][0]']
#  tchNormalization)
#
#  add (Add)                   (None, 6, 6, 64)             0         ['batch_normalization_1[0][0]'
#                                                                     , 'batch_normalization_2[0][0]
#                                                                     ',
#                                                                      'batch_normalization_3[0][0]'
#                                                                     , 'batch_normalization[0][0]']
#
#  add_16 (Add)                (None, 12, 12, 64)           0         ['batch_normalization_34[0][0]
#                                                                     ',
#                                                                      'batch_normalization_35[0][0]
#                                                                     ',
#                                                                      'batch_normalization_36[0][0]
#                                                                     ',
#                                                                      'batch_normalization_33[0][0]
#                                                                     ']
#
#  add_32 (Add)                (None, 25, 25, 64)           0         ['batch_normalization_67[0][0]
#                                                                     ',
#                                                                      'batch_normalization_68[0][0]
#                                                                     ',
#                                                                      'batch_normalization_69[0][0]
#                                                                     ',
#                                                                      'batch_normalization_66[0][0]
#                                                                     ']
#
#  conv2d_4 (Conv2D)           (None, 6, 6, 64)             4160      ['add[0][0]']
#
#  conv2d_29 (Conv2D)          (None, 12, 12, 64)           4160      ['add_16[0][0]']
#
#  conv2d_54 (Conv2D)          (None, 25, 25, 64)           4160      ['add_32[0][0]']
#
#  global_average_pooling2d (  (None, 64)                   0         ['conv2d_4[0][0]']
#  GlobalAveragePooling2D)
#
#  global_average_pooling2d_9  (None, 64)                   0         ['conv2d_29[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 64)                   0         ['conv2d_54[0][0]']
#  8 (GlobalAveragePooling2D)
#
#  tf.expand_dims (TFOpLambda  (None, 1, 64)                0         ['global_average_pooling2d[0][
#  )                                                                  0]']
#
#  tf.expand_dims_16 (TFOpLam  (None, 1, 64)                0         ['global_average_pooling2d_9[0
#  bda)                                                               ][0]']
#
#  tf.expand_dims_32 (TFOpLam  (None, 1, 64)                0         ['global_average_pooling2d_18[
#  bda)                                                               0][0]']
#
#  tf.expand_dims_1 (TFOpLamb  (None, 1, 1, 64)             0         ['tf.expand_dims[0][0]']
#  da)
#
#  tf.expand_dims_17 (TFOpLam  (None, 1, 1, 64)             0         ['tf.expand_dims_16[0][0]']
#  bda)
#
#  tf.expand_dims_33 (TFOpLam  (None, 1, 1, 64)             0         ['tf.expand_dims_32[0][0]']
#  bda)
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 16)             9232      ['tf.expand_dims_1[0][0]']
#
#  conv2d_30 (Conv2D)          (None, 1, 1, 16)             9232      ['tf.expand_dims_17[0][0]']
#
#  conv2d_55 (Conv2D)          (None, 1, 1, 16)             9232      ['tf.expand_dims_33[0][0]']
#
#  conv2d_6 (Conv2D)           (None, 1, 1, 64)             9280      ['conv2d_5[0][0]']
#
#  conv2d_31 (Conv2D)          (None, 1, 1, 64)             9280      ['conv2d_30[0][0]']
#
#  conv2d_56 (Conv2D)          (None, 1, 1, 64)             9280      ['conv2d_55[0][0]']
#
#  multiply (Multiply)         (None, 6, 6, 64)             0         ['conv2d_6[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  multiply_8 (Multiply)       (None, 12, 12, 64)           0         ['conv2d_31[0][0]',
#                                                                      'conv2d_29[0][0]']
#
#  multiply_16 (Multiply)      (None, 25, 25, 64)           0         ['conv2d_56[0][0]',
#                                                                      'conv2d_54[0][0]']
#
#  add_1 (Add)                 (None, 6, 6, 64)             0         ['multiply[0][0]',
#                                                                      'conv2d_4[0][0]']
#
#  add_17 (Add)                (None, 12, 12, 64)           0         ['multiply_8[0][0]',
#                                                                      'conv2d_29[0][0]']
#
#  add_33 (Add)                (None, 25, 25, 64)           0         ['multiply_16[0][0]',
#                                                                      'conv2d_54[0][0]']
#
#  activation_4 (Activation)   (None, 6, 6, 64)             0         ['add_1[0][0]']
#
#  activation_37 (Activation)  (None, 12, 12, 64)           0         ['add_17[0][0]']
#
#  activation_70 (Activation)  (None, 25, 25, 64)           0         ['add_33[0][0]']
#
#  batch_normalization_4 (Bat  (None, 6, 6, 64)             256       ['activation_4[0][0]']
#  chNormalization)
#
#  batch_normalization_37 (Ba  (None, 12, 12, 64)           256       ['activation_37[0][0]']
#  tchNormalization)
#
#  batch_normalization_70 (Ba  (None, 25, 25, 64)           256       ['activation_70[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_3 (Depthw  (None, 6, 6, 64)             128       ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  depthwise_conv2d_4 (Depthw  (None, 6, 6, 64)             640       ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  depthwise_conv2d_5 (Depthw  (None, 6, 6, 64)             1664      ['batch_normalization_4[0][0]'
#  iseConv2D)                                                         ]
#
#  depthwise_conv2d_27 (Depth  (None, 12, 12, 64)           128       ['batch_normalization_37[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_28 (Depth  (None, 12, 12, 64)           640       ['batch_normalization_37[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_29 (Depth  (None, 12, 12, 64)           1664      ['batch_normalization_37[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_51 (Depth  (None, 25, 25, 64)           128       ['batch_normalization_70[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_52 (Depth  (None, 25, 25, 64)           640       ['batch_normalization_70[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_53 (Depth  (None, 25, 25, 64)           1664      ['batch_normalization_70[0][0]
#  wiseConv2D)                                                        ']
#
#  activation_5 (Activation)   (None, 6, 6, 64)             0         ['depthwise_conv2d_3[0][0]']
#
#  activation_6 (Activation)   (None, 6, 6, 64)             0         ['depthwise_conv2d_4[0][0]']
#
#  activation_7 (Activation)   (None, 6, 6, 64)             0         ['depthwise_conv2d_5[0][0]']
#
#  activation_38 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_27[0][0]']
#
#  activation_39 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_28[0][0]']
#
#  activation_40 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_29[0][0]']
#
#  activation_71 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_51[0][0]']
#
#  activation_72 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_52[0][0]']
#
#  activation_73 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_53[0][0]']
#
#  batch_normalization_5 (Bat  (None, 6, 6, 64)             256       ['activation_5[0][0]']
#  chNormalization)
#
#  batch_normalization_6 (Bat  (None, 6, 6, 64)             256       ['activation_6[0][0]']
#  chNormalization)
#
#  batch_normalization_7 (Bat  (None, 6, 6, 64)             256       ['activation_7[0][0]']
#  chNormalization)
#
#  batch_normalization_38 (Ba  (None, 12, 12, 64)           256       ['activation_38[0][0]']
#  tchNormalization)
#
#  batch_normalization_39 (Ba  (None, 12, 12, 64)           256       ['activation_39[0][0]']
#  tchNormalization)
#
#  batch_normalization_40 (Ba  (None, 12, 12, 64)           256       ['activation_40[0][0]']
#  tchNormalization)
#
#  batch_normalization_71 (Ba  (None, 25, 25, 64)           256       ['activation_71[0][0]']
#  tchNormalization)
#
#  batch_normalization_72 (Ba  (None, 25, 25, 64)           256       ['activation_72[0][0]']
#  tchNormalization)
#
#  batch_normalization_73 (Ba  (None, 25, 25, 64)           256       ['activation_73[0][0]']
#  tchNormalization)
#
#  add_2 (Add)                 (None, 6, 6, 64)             0         ['batch_normalization_5[0][0]'
#                                                                     , 'batch_normalization_6[0][0]
#                                                                     ',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     , 'batch_normalization_4[0][0]
#                                                                     ']
#
#  add_18 (Add)                (None, 12, 12, 64)           0         ['batch_normalization_38[0][0]
#                                                                     ',
#                                                                      'batch_normalization_39[0][0]
#                                                                     ',
#                                                                      'batch_normalization_40[0][0]
#                                                                     ',
#                                                                      'batch_normalization_37[0][0]
#                                                                     ']
#
#  add_34 (Add)                (None, 25, 25, 64)           0         ['batch_normalization_71[0][0]
#                                                                     ',
#                                                                      'batch_normalization_72[0][0]
#                                                                     ',
#                                                                      'batch_normalization_73[0][0]
#                                                                     ',
#                                                                      'batch_normalization_70[0][0]
#                                                                     ']
#
#  conv2d_7 (Conv2D)           (None, 6, 6, 64)             4160      ['add_2[0][0]']
#
#  conv2d_32 (Conv2D)          (None, 12, 12, 64)           4160      ['add_18[0][0]']
#
#  conv2d_57 (Conv2D)          (None, 25, 25, 64)           4160      ['add_34[0][0]']
#
#  global_average_pooling2d_1  (None, 64)                   0         ['conv2d_7[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 64)                   0         ['conv2d_32[0][0]']
#  0 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 64)                   0         ['conv2d_57[0][0]']
#  9 (GlobalAveragePooling2D)
#
#  tf.expand_dims_2 (TFOpLamb  (None, 1, 64)                0         ['global_average_pooling2d_1[0
#  da)                                                                ][0]']
#
#  tf.expand_dims_18 (TFOpLam  (None, 1, 64)                0         ['global_average_pooling2d_10[
#  bda)                                                               0][0]']
#
#  tf.expand_dims_34 (TFOpLam  (None, 1, 64)                0         ['global_average_pooling2d_19[
#  bda)                                                               0][0]']
#
#  tf.expand_dims_3 (TFOpLamb  (None, 1, 1, 64)             0         ['tf.expand_dims_2[0][0]']
#  da)
#
#  tf.expand_dims_19 (TFOpLam  (None, 1, 1, 64)             0         ['tf.expand_dims_18[0][0]']
#  bda)
#
#  tf.expand_dims_35 (TFOpLam  (None, 1, 1, 64)             0         ['tf.expand_dims_34[0][0]']
#  bda)
#
#  conv2d_8 (Conv2D)           (None, 1, 1, 16)             9232      ['tf.expand_dims_3[0][0]']
#
#  conv2d_33 (Conv2D)          (None, 1, 1, 16)             9232      ['tf.expand_dims_19[0][0]']
#
#  conv2d_58 (Conv2D)          (None, 1, 1, 16)             9232      ['tf.expand_dims_35[0][0]']
#
#  conv2d_9 (Conv2D)           (None, 1, 1, 64)             9280      ['conv2d_8[0][0]']
#
#  conv2d_34 (Conv2D)          (None, 1, 1, 64)             9280      ['conv2d_33[0][0]']
#
#  conv2d_59 (Conv2D)          (None, 1, 1, 64)             9280      ['conv2d_58[0][0]']
#
#  multiply_1 (Multiply)       (None, 6, 6, 64)             0         ['conv2d_9[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  multiply_9 (Multiply)       (None, 12, 12, 64)           0         ['conv2d_34[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  multiply_17 (Multiply)      (None, 25, 25, 64)           0         ['conv2d_59[0][0]',
#                                                                      'conv2d_57[0][0]']
#
#  add_3 (Add)                 (None, 6, 6, 64)             0         ['multiply_1[0][0]',
#                                                                      'conv2d_7[0][0]']
#
#  add_19 (Add)                (None, 12, 12, 64)           0         ['multiply_9[0][0]',
#                                                                      'conv2d_32[0][0]']
#
#  add_35 (Add)                (None, 25, 25, 64)           0         ['multiply_17[0][0]',
#                                                                      'conv2d_57[0][0]']
#
#  activation_8 (Activation)   (None, 6, 6, 64)             0         ['add_3[0][0]']
#
#  activation_41 (Activation)  (None, 12, 12, 64)           0         ['add_19[0][0]']
#
#  activation_74 (Activation)  (None, 25, 25, 64)           0         ['add_35[0][0]']
#
#  batch_normalization_8 (Bat  (None, 6, 6, 64)             256       ['activation_8[0][0]']
#  chNormalization)
#
#  batch_normalization_41 (Ba  (None, 12, 12, 64)           256       ['activation_41[0][0]']
#  tchNormalization)
#
#  batch_normalization_74 (Ba  (None, 25, 25, 64)           256       ['activation_74[0][0]']
#  tchNormalization)
#
#  depthwise_conv2d_6 (Depthw  (None, 6, 6, 64)             128       ['batch_normalization_8[0][0]'
#  iseConv2D)                                                         ]
#
#  depthwise_conv2d_7 (Depthw  (None, 6, 6, 64)             640       ['batch_normalization_8[0][0]'
#  iseConv2D)                                                         ]
#
#  depthwise_conv2d_8 (Depthw  (None, 6, 6, 64)             1664      ['batch_normalization_8[0][0]'
#  iseConv2D)                                                         ]
#
#  depthwise_conv2d_30 (Depth  (None, 12, 12, 64)           128       ['batch_normalization_41[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_31 (Depth  (None, 12, 12, 64)           640       ['batch_normalization_41[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_32 (Depth  (None, 12, 12, 64)           1664      ['batch_normalization_41[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_54 (Depth  (None, 25, 25, 64)           128       ['batch_normalization_74[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_55 (Depth  (None, 25, 25, 64)           640       ['batch_normalization_74[0][0]
#  wiseConv2D)                                                        ']
#
#  depthwise_conv2d_56 (Depth  (None, 25, 25, 64)           1664      ['batch_normalization_74[0][0]
#  wiseConv2D)                                                        ']
#
#  activation_9 (Activation)   (None, 6, 6, 64)             0         ['depthwise_conv2d_6[0][0]']
#
#  activation_10 (Activation)  (None, 6, 6, 64)             0         ['depthwise_conv2d_7[0][0]']
#
#  activation_11 (Activation)  (None, 6, 6, 64)             0         ['depthwise_conv2d_8[0][0]']
#
#  activation_42 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_30[0][0]']
#
#  activation_43 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_31[0][0]']
#
#  activation_44 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_32[0][0]']
#
#  activation_75 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_54[0][0]']
#
#  activation_76 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_55[0][0]']
#
#  activation_77 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_56[0][0]']
#
#  batch_normalization_9 (Bat  (None, 6, 6, 64)             256       ['activation_9[0][0]']
#  chNormalization)
#
#  batch_normalization_10 (Ba  (None, 6, 6, 64)             256       ['activation_10[0][0]']
#  tchNormalization)
#
#  batch_normalization_11 (Ba  (None, 6, 6, 64)             256       ['activation_11[0][0]']
#  tchNormalization)
#
#  batch_normalization_42 (Ba  (None, 12, 12, 64)           256       ['activation_42[0][0]']
#  tchNormalization)
#
#  batch_normalization_43 (Ba  (None, 12, 12, 64)           256       ['activation_43[0][0]']
#  tchNormalization)
#
#  batch_normalization_44 (Ba  (None, 12, 12, 64)           256       ['activation_44[0][0]']
#  tchNormalization)
#
#  batch_normalization_75 (Ba  (None, 25, 25, 64)           256       ['activation_75[0][0]']
#  tchNormalization)
#
#  batch_normalization_76 (Ba  (None, 25, 25, 64)           256       ['activation_76[0][0]']
#  tchNormalization)
#
#  batch_normalization_77 (Ba  (None, 25, 25, 64)           256       ['activation_77[0][0]']
#  tchNormalization)
#
#  add_4 (Add)                 (None, 6, 6, 64)             0         ['batch_normalization_9[0][0]'
#                                                                     , 'batch_normalization_10[0][0
#                                                                     ]',
#                                                                      'batch_normalization_11[0][0]
#                                                                     ',
#                                                                      'batch_normalization_8[0][0]'
#                                                                     ]
#
#  add_20 (Add)                (None, 12, 12, 64)           0         ['batch_normalization_42[0][0]
#                                                                     ',
#                                                                      'batch_normalization_43[0][0]
#                                                                     ',
#                                                                      'batch_normalization_44[0][0]
#                                                                     ',
#                                                                      'batch_normalization_41[0][0]
#                                                                     ']
#
#  add_36 (Add)                (None, 25, 25, 64)           0         ['batch_normalization_75[0][0]
#                                                                     ',
#                                                                      'batch_normalization_76[0][0]
#                                                                     ',
#                                                                      'batch_normalization_77[0][0]
#                                                                     ',
#                                                                      'batch_normalization_74[0][0]
#                                                                     ']
# ...
#  activation_63 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_46[0][0]']
#
#  activation_64 (Activation)  (None, 12, 12, 64)           0         ['depthwise_conv2d_47[0][0]']
#
#  activation_95 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_69[0][0]']
#
#  activation_96 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_70[0][0]']
#
#  activation_97 (Activation)  (None, 25, 25, 64)           0         ['depthwise_conv2d_71[0][0]']
#
#  batch_normalization_29 (Ba  (None, 6, 6, 64)             256       ['activation_29[0][0]']
#  tchNormalization)
#
#  batch_normalization_30 (Ba  (None, 6, 6, 64)             256       ['activation_30[0][0]']
#  tchNormalization)
#
#  batch_normalization_31 (Ba  (None, 6, 6, 64)             256       ['activation_31[0][0]']
#  tchNormalization)
#
#  batch_normalization_62 (Ba  (None, 12, 12, 64)           256       ['activation_62[0][0]']
#  tchNormalization)
#
#  batch_normalization_63 (Ba  (None, 12, 12, 64)           256       ['activation_63[0][0]']
#  tchNormalization)
#
#  batch_normalization_64 (Ba  (None, 12, 12, 64)           256       ['activation_64[0][0]']
#  tchNormalization)
#
#  batch_normalization_95 (Ba  (None, 25, 25, 64)           256       ['activation_95[0][0]']
#  tchNormalization)
#
#  batch_normalization_96 (Ba  (None, 25, 25, 64)           256       ['activation_96[0][0]']
#  tchNormalization)
#
#  batch_normalization_97 (Ba  (None, 25, 25, 64)           256       ['activation_97[0][0]']
#  tchNormalization)
#
#  add_14 (Add)                (None, 6, 6, 64)             0         ['batch_normalization_29[0][0]
#                                                                     ',
#                                                                      'batch_normalization_30[0][0]
#                                                                     ',
#                                                                      'batch_normalization_31[0][0]
#                                                                     ',
#                                                                      'batch_normalization_28[0][0]
#                                                                     ']
#
#  add_30 (Add)                (None, 12, 12, 64)           0         ['batch_normalization_62[0][0]
#                                                                     ',
#                                                                      'batch_normalization_63[0][0]
#                                                                     ',
#                                                                      'batch_normalization_64[0][0]
#                                                                     ',
#                                                                      'batch_normalization_61[0][0]
#                                                                     ']
#
#  add_46 (Add)                (None, 25, 25, 64)           0         ['batch_normalization_95[0][0]
#                                                                     ',
#                                                                      'batch_normalization_96[0][0]
#                                                                     ',
#                                                                      'batch_normalization_97[0][0]
#                                                                     ',
#                                                                      'batch_normalization_94[0][0]
#                                                                     ']
#
#  conv2d_25 (Conv2D)          (None, 6, 6, 64)             4160      ['add_14[0][0]']
#
#  conv2d_50 (Conv2D)          (None, 12, 12, 64)           4160      ['add_30[0][0]']
#
#  conv2d_75 (Conv2D)          (None, 25, 25, 64)           4160      ['add_46[0][0]']
#
#  global_average_pooling2d_7  (None, 64)                   0         ['conv2d_25[0][0]']
#   (GlobalAveragePooling2D)
#
#  global_average_pooling2d_1  (None, 64)                   0         ['conv2d_50[0][0]']
#  6 (GlobalAveragePooling2D)
#
#  global_average_pooling2d_2  (None, 64)                   0         ['conv2d_75[0][0]']
#  5 (GlobalAveragePooling2D)
#
#  tf.expand_dims_14 (TFOpLam  (None, 1, 64)                0         ['global_average_pooling2d_7[0
#  bda)                                                               ][0]']
#
#  tf.expand_dims_30 (TFOpLam  (None, 1, 64)                0         ['global_average_pooling2d_16[
#  bda)                                                               0][0]']
#
#  tf.expand_dims_46 (TFOpLam  (None, 1, 64)                0         ['global_average_pooling2d_25[
#  bda)                                                               0][0]']
#
#  tf.expand_dims_15 (TFOpLam  (None, 1, 1, 64)             0         ['tf.expand_dims_14[0][0]']
#  bda)
#
#  tf.expand_dims_31 (TFOpLam  (None, 1, 1, 64)             0         ['tf.expand_dims_30[0][0]']
#  bda)
#
#  tf.expand_dims_47 (TFOpLam  (None, 1, 1, 64)             0         ['tf.expand_dims_46[0][0]']
#  bda)
#
#  conv2d_26 (Conv2D)          (None, 1, 1, 16)             9232      ['tf.expand_dims_15[0][0]']
#
#  conv2d_51 (Conv2D)          (None, 1, 1, 16)             9232      ['tf.expand_dims_31[0][0]']
#
#  conv2d_76 (Conv2D)          (None, 1, 1, 16)             9232      ['tf.expand_dims_47[0][0]']
#
#  conv2d_27 (Conv2D)          (None, 1, 1, 64)             9280      ['conv2d_26[0][0]']
#
#  conv2d_52 (Conv2D)          (None, 1, 1, 64)             9280      ['conv2d_51[0][0]']
#
#  conv2d_77 (Conv2D)          (None, 1, 1, 64)             9280      ['conv2d_76[0][0]']
#
#  multiply_7 (Multiply)       (None, 6, 6, 64)             0         ['conv2d_27[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  multiply_15 (Multiply)      (None, 12, 12, 64)           0         ['conv2d_52[0][0]',
#                                                                      'conv2d_50[0][0]']
#
#  multiply_23 (Multiply)      (None, 25, 25, 64)           0         ['conv2d_77[0][0]',
#                                                                      'conv2d_75[0][0]']
#
#  add_15 (Add)                (None, 6, 6, 64)             0         ['multiply_7[0][0]',
#                                                                      'conv2d_25[0][0]']
#
#  add_31 (Add)                (None, 12, 12, 64)           0         ['multiply_15[0][0]',
#                                                                      'conv2d_50[0][0]']
#
#  add_47 (Add)                (None, 25, 25, 64)           0         ['multiply_23[0][0]',
#                                                                      'conv2d_75[0][0]']
#
#  activation_32 (Activation)  (None, 6, 6, 64)             0         ['add_15[0][0]']
#
#  activation_65 (Activation)  (None, 12, 12, 64)           0         ['add_31[0][0]']
#
#  activation_98 (Activation)  (None, 25, 25, 64)           0         ['add_47[0][0]']
#
#  batch_normalization_32 (Ba  (None, 6, 6, 64)             256       ['activation_32[0][0]']
#  tchNormalization)
#
#  batch_normalization_65 (Ba  (None, 12, 12, 64)           256       ['activation_65[0][0]']
#  tchNormalization)
#
#  batch_normalization_98 (Ba  (None, 25, 25, 64)           256       ['activation_98[0][0]']
#  tchNormalization)
#
#  global_average_pooling2d_8  (None, 64)                   0         ['batch_normalization_32[0][0]
#   (GlobalAveragePooling2D)                                          ']
#
#  global_average_pooling2d_1  (None, 64)                   0         ['batch_normalization_65[0][0]
#  7 (GlobalAveragePooling2D)                                         ']
#
#  global_average_pooling2d_2  (None, 64)                   0         ['batch_normalization_98[0][0]
#  6 (GlobalAveragePooling2D)                                         ']
#
#  concatenate (Concatenate)   (None, 192)                  0         ['global_average_pooling2d_8[0
#                                                                     ][0]',
#                                                                      'global_average_pooling2d_17[
#                                                                     0][0]',
#                                                                      'global_average_pooling2d_26[
#                                                                     0][0]']
#
# ==================================================================================================
# Total params: 630450 (2.40 MB)
# Trainable params: 617778 (2.36 MB)
# Non-trainable params: 12672 (49.50 KB)
# __________________________________________________________________________________________________

# %%
cb_y
# Out:
# <KerasTensor: shape=(None, 192) dtype=float32 (created by layer 'concatenate')>

# %% [markdown]
# **Assuming, the data comes in as ( batch, height, width, band, channel)**

# %%
 #

filters = 64
kernel_size = 3
dropout = 0.3
patch_size = 2
depths = 8

number_class = output_units

h_dmn = height_dim # height

w_dmn = width_dim # width

ch_dmn = cahnnel_dim # chnnel


b_dmn = band_dim # band

cb_dmn = 10 # band_cluster # As, cv_dmn-->b_dmn, model will be slower and inverse is true also. So, its a hyperparameter,
            #and sweetspot is needed for best performance acc/speed.

grps = b_dmn//cb_dmn


inputs = Input((height_dim, width_dim, band_dim, cahnnel_dim ))


outputs = []


for i in range(grps):

    b_clusters = inputs[ :,:,:,i*cb_dmn: (i+1)*cb_dmn,: ]

    outputs.append(  bone_mixer(tf.reduce_sum( b_clusters,3)))

av_band =  concatenate(outputs,1)
av_band = Dropout(rate= 0.5, seed= 123)(av_band)

y = Dense(256, kernel_regularizer= l2(l= 0.016), activation= 'relu') (av_band )
y = Dropout(rate= 0.35, seed= 123)(y)

outputs = Dense(number_class, activation='softmax')(y)


pyra_3d_mixer_model_band_last =  Model(inputs=inputs, outputs=outputs )


pyra_3d_mixer_model_band_last .summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 25, 25, 30, 1)]      0         []
#
#  tf.__operators__.getitem (  (None, 25, 25, 10, 1)        0         ['input_2[0][0]']
#  SlicingOpLambda)
#
#  tf.__operators__.getitem_1  (None, 25, 25, 10, 1)        0         ['input_2[0][0]']
#   (SlicingOpLambda)
#
#  tf.__operators__.getitem_2  (None, 25, 25, 10, 1)        0         ['input_2[0][0]']
#   (SlicingOpLambda)
#
#  tf.math.reduce_sum (TFOpLa  (None, 25, 25, 1)            0         ['tf.__operators__.getitem[0][
#  mbda)                                                              0]']
#
#  tf.math.reduce_sum_1 (TFOp  (None, 25, 25, 1)            0         ['tf.__operators__.getitem_1[0
#  Lambda)                                                            ][0]']
#
#  tf.math.reduce_sum_2 (TFOp  (None, 25, 25, 1)            0         ['tf.__operators__.getitem_2[0
#  Lambda)                                                            ][0]']
#
#  model (Functional)          (None, 192)                  630450    ['tf.math.reduce_sum[0][0]',
#                                                                      'tf.math.reduce_sum_1[0][0]',
#                                                                      'tf.math.reduce_sum_2[0][0]']
#
#  concatenate_1 (Concatenate  (None, 576)                  0         ['model[0][0]',
#  )                                                                   'model[1][0]',
#                                                                      'model[2][0]']
#
#  dropout (Dropout)           (None, 576)                  0         ['concatenate_1[0][0]']
#
#  dense (Dense)               (None, 256)                  147712    ['dropout[0][0]']
#
#  dropout_1 (Dropout)         (None, 256)                  0         ['dense[0][0]']
#
#  dense_1 (Dense)             (None, 16)                   4112      ['dropout_1[0][0]']
#
# ==================================================================================================
# Total params: 782274 (2.98 MB)
# Trainable params: 769602 (2.94 MB)
# Non-trainable params: 12672 (49.50 KB)
# __________________________________________________________________________________________________

# %%
# from keras.optimizers import Adam
# # compiling the model
# adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, decay=1e-06)
# bone_mixer.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# # checkpoint
# filepath = "gdrive/My Drive/HIS_Final/best-model.hdf5"
# checkpoint = ModelCheckpoint(filepath, monitor='acc', verbose=1, save_best_only=True, mode='max')
# callbacks_list = [checkpoint]

# history = bone_mixer.fit(x=Xtrain, y=ytrain, batch_size=256, epochs=15, callbacks=callbacks_list)

# %%
print(Xtrain.shape,  ytrain.shape)
# Out:
# (3074, 25, 25, 30, 1) (3074, 16)

# %%
from keras.optimizers import Adam
# compiling the model
adam = tf.keras.optimizers.legacy.Adam(learning_rate=0.001, decay=1e-06)
pyra_3d_mixer_model_band_last.compile(loss='categorical_crossentropy', optimizer=adam, metrics=['accuracy'])

# %%
# checkpoint
filepath = "gdrive/My Drive/HIS_Final/best-model.hdf5"
checkpoint = ModelCheckpoint(filepath, monitor='acc', verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]

# %%
history = pyra_3d_mixer_model_band_last.fit(x=Xtrain, y=ytrain, batch_size=32, epochs=10, callbacks=callbacks_list)
# Out:
# Epoch 1/10
# 97/97 [==============================] - ETA: 0s - loss: 4.3521 - accuracy: 0.6571
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 118s 293ms/step - loss: 4.3521 - accuracy: 0.6571
# Epoch 2/10
# 97/97 [==============================] - ETA: 0s - loss: 1.3744 - accuracy: 0.9021
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 289ms/step - loss: 1.3744 - accuracy: 0.9021
# Epoch 3/10
# 97/97 [==============================] - ETA: 0s - loss: 0.6830 - accuracy: 0.9408
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 289ms/step - loss: 0.6830 - accuracy: 0.9408
# Epoch 4/10
# 97/97 [==============================] - ETA: 0s - loss: 0.5093 - accuracy: 0.9333
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 290ms/step - loss: 0.5093 - accuracy: 0.9333
# Epoch 5/10
# 97/97 [==============================] - ETA: 0s - loss: 0.3933 - accuracy: 0.9577
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 290ms/step - loss: 0.3933 - accuracy: 0.9577
# Epoch 6/10
# 97/97 [==============================] - ETA: 0s - loss: 0.3648 - accuracy: 0.9626
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 291ms/step - loss: 0.3648 - accuracy: 0.9626
# Epoch 7/10
# 97/97 [==============================] - ETA: 0s - loss: 0.2672 - accuracy: 0.9808
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 291ms/step - loss: 0.2672 - accuracy: 0.9808
# Epoch 8/10
# 97/97 [==============================] - ETA: 0s - loss: 0.3032 - accuracy: 0.9642
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 291ms/step - loss: 0.3032 - accuracy: 0.9642
# Epoch 9/10
# 97/97 [==============================] - ETA: 0s - loss: 0.3356 - accuracy: 0.9684
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 292ms/step - loss: 0.3356 - accuracy: 0.9684
# Epoch 10/10
# 97/97 [==============================] - ETA: 0s - loss: 0.3901 - accuracy: 0.9574
# WARNING:tensorflow:Can save best model only with acc available, skipping.
# 97/97 [==============================] - 28s 292ms/step - loss: 0.3901 - accuracy: 0.9574

# %%
Xtest_1, ytest_1 = np.expand_dims(Xtest,-1),  keras_to_categorical(ytest)
print(Xtest_1.shape, ytest_1.shape)
# Out:
# (7175, 25, 25, 30, 1) (7175, 16)

# %%
loss_v , accuracy_v = pyra_3d_mixer_model_band_last.evaluate(Xtest_1, ytest_1)
# Out:
# 225/225 [==============================] - 31s 91ms/step - loss: 0.4490 - accuracy: 0.9268
